# %% [markdown]
# <div style="text-align: left;">
#
# ## Módulo: ED-NA-001 - Extração de Dados I
# <br>
#
# ## Aula 6 - Exercício 1 - Parte 1
# <br>

# %% [markdown]
# #### Desenvolver um pipeline de dados para a análise de sentimento de notícias relacionadas ao Bitcoin usando dados obtidos da API Alpha Vantage (https://www.alphavantage.co/documentation/) com os seguintes passos:
#
# > #### 1: Fazer uma chamada à API Alpha Vantage com a função NEWS_SENTIMENT para obter dados de sentimento de notícias relacionadas ao Bitcoin. Exemplo a seguir:
# > #### 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=CRYPTO:BTC&time_from=20230926T0000&limit=1000&apikey=' + api_key'
#
# #### 'function=NEWS_SENTIMENT':  Este é o parâmetro que especifica a função da API que está sendo chamada, neste caso, a função "NEWS_SENTIMENT" que retorna informações de sentimento de notícias.
#
# #### 'tickers=CRYPTO:BTC': Neste parâmetro, é especificado o ticker do ativo financeiro que deseja ser analisado. No caso em questão, é "CRYPTO:BTC", indicando que análises de sentimento de notícias relacionadas ao Bitcoin estão sendo solicitadas.
#
# #### 'time_from=20230926T0000': Este parâmetro define a data e hora a partir das quais as informações de sentimento de notícias são solicitadas. No exemplo fornecido, a data é definida como 26 de setembro de 2023 às 00:00 (meia-noite).
#
# #### 'limit=1000': Este parâmetro define o número máximo de notícias a serem recuperadas. No exemplo mencionado, a busca está limitada a 1000 notícias.
#
# #### 'apikey=': Aqui é preciso adicionar a chave da API adquirida via login no site da API.
#
# #### O resultado dessa chamada à API será um conjunto de informações de sentimento de notícias relacionadas ao Bitcoin, incluindo possíveis métricas de sentimento, pontuações, resumos ou outros dados relevantes. O formato e a estrutura exatos dos dados dependem da API Alpha Vantage e das informações disponíveis em seu serviço no momento da chamada.

# %% [markdown]
# ### Exemplo da chamada

# %%
# %run ./api_key

# %%
import requests 

url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=CRYPTO:BTC&time_from=20230926T0000&limit=1000&apikey=' + api_key
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'items': '52', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': "SEC Again Delays Decision on Ark's Bitcoin ETF Filing", 'url': 'https://decrypt.co/198888/sec-delays-spot-bitcoin-etf-decision-second-time', 'time_published': '20230927T001100', 'authors': ['Andrew Throuvalas'], 'summary': "The SEC made the call this week, even though it wasn't required to issue a decision until November 11.", 'banner_image': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2023/02/sec-crypto-regulations-gID_7.jpg', 'source': 'Decrypt.co', 'category_within_source': 'n/a', 'source_domain': 'decrypt.co', 'topics': [{'topic': 'Finance', 'relevance_score': '1.0'}, {'topic': 'Financial Markets', 'relevance_score': '0.9545'}], 'overall_sentiment_score': -0.017076, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'BLK', 'relevance_score': '0.113062', 'ticker_sentiment_score': '-0.120473', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'CRYPTO:BTC', 'relevance_score': '0.430454', 'ticker_sentiment_score': '0.014998', 'ticker_sentiment_label': 'Neutral'}]}, {'title': 'Texas Is Now the Top US Bitcoin Mining Spot: Foundry', 'url': 'https://decrypt.co/198889/texas-top-us-state-for-bitcoin-mining-foundry-cambridge', 'time_published': '20230926T235815', 'authors': ['Andrew Throuvalas'], 'summary': 'A digital asset researcher at Cambridge says the region\'s dominance "does not come as a surprise." ...', 'banner_image': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2021/05/texas-bitcoin-mining-gID_7.jpg', 'source': 'Decrypt.co', 'category_within_source': 'n/a', 'source_domain': 'decrypt.co', 'topics': [{'topic': 'Real Estate & Construction', 'relevance_score': '1.0'}], 'overall_sentiment_score': 0.050622, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'CIFR', 'relevance_score': '0.074926', 'ticker_sentiment_score': '-0.067584', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'CRYPTO:BTC', 'relevance_score': '0.293214', 'ticker_sentiment_score': '-0.029683', 'ticker_sentiment_label': 'Neutral'}]}, {'title': 'Ethereum Reaches $10B Revenue In Seven Years For A Win Against Tech Majors', 'url': 'https://www.benzinga.com/markets/cryptocurrency/23/09/34927774/ethereum-reaches-10b-revenue-in-seven-years-for-a-win-against-tech-majors', 'time_published': '20230926T234221', 'authors': ['Khyathi Dalal'], 'summary': "Ethereum ETH/USD managed to get to revenue levels that tech majors failed to reach after years of operations. The platform's diverse revenue sources and strong network activities were the driving factors.", 'banner_image': 'https://cdn.benzinga.com/files/images/story/2023/09/26/ethereum.kanchanara-vu13qdltqyu-unsplash.jpg?width=1200&height=800&fit=crop', 'source': 'Benzinga', 'category_within_source': 'Markets', 'source_domain': 'www.benzinga.com', 'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.538269'}, {'topic': 'Earnings', 'relevance_score': '0.316726'}, {'topic': 'Technology', 'relevance_score': '1.0'}, {'topic': 'Blockchain', 'relevance_score': '0.310843'}], 'overall_sentiment_score': 0.045533, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'ADBE', 'relevance_score': '0.238133', 'ticker_sentiment_score': '0.182324', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'MSFT', 'relevance_score': '0.238133', 'ticker_sentiment_score': '0.182324', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'GOOG', 'relevance_score': '0.120431', 'ticker_sentiment_score': '0.11684', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'CRYPTO:BTC', 'relevance_score': '0.120431', 'ticker_sentiment_score': '-0.019335', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'CRYPTO:ETH', 'relevance_score': '0.636698' ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# platform-hides-license-after-inquiry', 'time_published': '20230926T110943', 'authors': ['Helen Partz'], 'summary': 'A crypto exchange claiming $1.7 billion in daily trades and reporting $1.4 billion on CoinMarketCap had reportedly displayed false license data until Estonian regulators checked it.', 'banner_image': 'https://s3.cointelegraph.com/uploads/2023-09/97f110a0-41c5-4ff7-bb66-63b5308d462f.png', 'source': 'Cointelegraph', 'category_within_source': 'n/a', 'source_domain': 'cointelegraph.com', 'topics': [{'topic': 'Blockchain', 'relevance_score': '0.682689'}, {'topic': 'Financial Markets', 'relevance_score': '0.413559'}], 'overall_sentiment_score': -0.051904, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'CRYPTO:BTC', 'relevance_score': '0.104002', 'ticker_sentiment_score': '-0.035333', 'ticker_sentiment_label': 'Neutral'}]}, {'title': "PREVIEW - Sam Bankman-Fried's trial to test dueling explanations for collapse of crypto exchange", 'url': 'https://www.financialexpress.com/business/digital-transformation-preview-sam-bankman-frieds-trial-to-test-dueling-explanations-for-collapse-of-crypto-exchange-3255468/', 'time_published': '20230926T110000', 'authors': ['Reuters'], 'summary': "In U.S. prosecutors' telling, Sam Bankman-Fried embezzled money from depositors in his FTX cryptocurrency exchange ever since he launched it in 2019, and the resulting shortfall led directly to its collapse as crypto prices swooned last year.", 'banner_image': 'https://www.financialexpress.com/wp-content/uploads/2023/09/Untitled-design-2023-09-26T161805.519.jpg', 'source': 'The Financial Express', 'category_within_source': 'n/a', 'source_domain': 'www.financialexpress.com', 'topics': [{'topic': 'Blockchain', 'relevance_score': '0.451494'}, {'topic': 'Manufacturing', 'relevance_score': '1.0'}], 'overall_sentiment_score': -0.077274, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'NYT', 'relevance_score': '0.083687', 'ticker_sentiment_score': '-0.077158', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'CRYPTO:BTC', 'relevance_score': '0.041901', 'ticker_sentiment_score': '-0.070789', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'CRYPTO:FTT', 'relevance_score': '0.041901', 'ticker_sentiment_score': '-0.071308', 'ticker_sentiment_label': 'Neutral'}]}, {'title': 'Celsius Network Creditors Approve $2B Restructuring Plan', 'url': 'https://decrypt.co/198736/celsius-network-creditors-approve-2b-restructuring-plan', 'time_published': '20230926T105644', 'authors': ['Andrew Asmakov'], 'summary': "Celsius Network's reorganization plan received overwhelming support from creditors, pending final approval from the U.S. Bankruptcy Court.", 'banner_image': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2022/06/celsius-network-gID_7.jpg', 'source': 'Decrypt.co', 'category_within_source': 'n/a', 'source_domain': 'decrypt.co', 'topics': [{'topic': 'Finance', 'relevance_score': '1.0'}, {'topic': 'Blockchain', 'relevance_score': '0.310843'}, {'topic': 'Financial Markets', 'relevance_score': '0.796627'}], 'overall_sentiment_score': 0.116458, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'COIN', 'relevance_score': '0.15697', 'ticker_sentiment_score': '-0.085574', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'CRYPTO:BTC', 'relevance_score': '0.379435', 'ticker_sentiment_score': '0.24648', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'CRYPTO:ETH', 'relevance_score': '0.233556', 'ticker_sentiment_score': '0.171379', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'CRYPTO:ALGO', 'relevance_score': '0.07887', 'ticker_sentiment_score': '0.099469', 'ticker_sentiment_label': 'Neutral'}]}, {'title': '2 Cryptocurrencies That Are Down 20% or More and Ready to Pop', 'url': 'https://www.fool.com/investing/2023/09/26/2-cryptocurrencies-down-and-ready-to-pop/', 'time_published': '20230926T104000', 'authors': ['Dominic Basulto'], 'summary': "Avalanche and Polygon coul ...

# %% [markdown]
# ### Os resultados da primeira notícia encontrada:

# %%
data['feed'][0]
# Out:
# Out[5]: {'title': "SEC Again Delays Decision on Ark's Bitcoin ETF Filing",
#  'url': 'https://decrypt.co/198888/sec-delays-spot-bitcoin-etf-decision-second-time',
#  'time_published': '20230927T001100',
#  'authors': ['Andrew Throuvalas'],
#  'summary': "The SEC made the call this week, even though it wasn't required to issue a decision until November 11.",
#  'banner_image': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2023/02/sec-crypto-regulations-gID_7.jpg',
#  'source': 'Decrypt.co',
#  'category_within_source': 'n/a',
#  'source_domain': 'decrypt.co',
#  'topics': [{'topic': 'Finance', 'relevance_score': '1.0'},
#   {'topic': 'Financial Markets', 'relevance_score': '0.9545'}],
#  'overall_sentiment_score': -0.017076,
#  'overall_sentiment_label': 'Neutral',
#  'ticker_sentiment': [{'ticker': 'BLK',
#    'relevance_score': '0.113062',
#    'ticker_sentiment_score': '-0.120473',
#    'ticker_sentiment_label': 'Neutral'},
#   {'ticker': 'CRYPTO:BTC',
#    'relevance_score': '0.430454',
#    'ticker_sentiment_score': '0.014998',
#    'ticker_sentiment_label': 'Neutral'}]}

# %% [markdown]
# > ### 2. Efetuado a chamada, será preciso encontrar uma chave única por notícia para evitar duplicidades no pipeline e o mínimo de informações por notícia que será necessário armazenar é o título, data de publicação e o resultado da análise de sentimento para o Bitcoin, exemplo a seguir com todas essas informações necessárias da última nóticia:

# %%
print("Resultado para a primeira notícia encontrada:")
print("Título", data['feed'][0]['title'])
print("Data de publicação", data['feed'][0]['time_published'])
print("Resultado apenas do Ticker igual ao Bitcoin ('CRYPTO:BTC')", data['feed'][0]['ticker_sentiment'][1])
# Out:
# Resultado para a primeira notícia encontrada:
# Título SEC Again Delays Decision on Ark's Bitcoin ETF Filing
# Data de publicação 20230927T001100
# Resultado apenas do Ticker igual ao Bitcoin ('CRYPTO:BTC') {'ticker': 'CRYPTO:BTC', 'relevance_score': '0.430454', 'ticker_sentiment_score': '0.014998', 'ticker_sentiment_label': 'Neutral'}

# %% [markdown]
# > ### 3. Preparar um pipeline capaz de extrair e armazenar essas informações com uma atualização diária, não permitindo duplicadas na base final.

# %% [markdown]
# > ### 4. Por fim, desenvolver um pipeline de dados transformados para contabilizar a quantidade de notícias encontradas por dia, e o "sentimento médio" por dia, atualizando diariamente também.
